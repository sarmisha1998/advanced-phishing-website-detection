# %%
import sys
sys.path.append('..')

import pandas as pd
from src.features import extract_url_features

# Load dataset
df = pd.read_csv('../data/sample_urls.csv')

# Extract features
features = [extract_url_features(url) for url in df['url']]

# Display features as DataFrame
pd.DataFrame(features)
# Out:
#    url_length  count_dot  count_hyphen  count_at  has_https  has_ip  \
# 0          25          3             0         0          0       1
# 1          31          1             1         0          0       0
# 2          22          2             0         0          1       0
# 3          18          1             0         0          1       0
# 4          18          1             0         0          1       0
#
#    domain_length  subdomain_length
# 0             12                 0
# 1             13                 0
# 2              6                 3
# 3              6                 0
# 4              6                 0
